# %%
# This project uses ThermalGen for RGB-to-thermal image generation.
# Model: ThermalGen-XL-2
# Repository: https://github.com/xjh19972/ThermalGen
# If you use this model in research, please cite the ThermalGen paper.

# The notebook illustration was developed by Arcknow.
# Author: Haoyun Feng
# The code is shared openly for research and educational use. Attribution appreciated.

# %%
# %pip install torch torchvision diffusers huggingface_hub pillow torchdiffeq timm einops accelerate torchmetrics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (2.10.0+cu130)
# Requirement already satisfied: torchvision in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (0.25.0+cu130)
# Requirement already satisfied: diffusers in /home/grwaqo/.local/lib/python3.12/site-packages (0.37.0)
# Requirement already satisfied: huggingface_hub in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (1.6.0)
# Requirement already satisfied: pillow in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (12.1.1)
# Requirement already satisfied: torchdiffeq in /home/grwaqo/.local/lib/python3.12/site-packages (0.2.5)
# Requirement already satisfied: timm in /home/grwaqo/.local/lib/python3.12/site-packages (1.0.25)
# Requirement already satisfied: einops in /home/grwaqo/.local/lib/python3.12/site-packages (0.8.2)
# Requirement already satisfied: accelerate in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (1.13.0)
# Requirement already satisfied: torchmetrics in /home/grwaqo/.local/lib/python3.12/site-packages (1.9.0)
# Requirement already satisfied: filelock in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (82.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (2025.12.0)
# Requirement already satisfied: cuda-bindings==13.0.3 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (13.0.3)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (13.0.88)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (13.0.96)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (13.0.85)
# Requirement already satisfied: nvidia-cudnn-cu13==9.15.1.9 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (9.15.1.9)
# Requirement already satisfied: nvidia-cublas==13.1.0.3 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (13.1.0.3)
# Requirement already satisfied: nvidia-cufft==12.0.0.61 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (12.0.0.61)
# Requirement already satisfied: nvidia-curand==10.4.0.35 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (12.6.3.3)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx==13.0.85 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (13.0.85)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (13.0.88)
# Requirement already satisfied: nvidia-cufile==1.15.1.6 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (1.15.1.6)
# Requirement already satisfied: triton==3.6.0 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from cuda-bindings==13.0.3->torch) (1.2.2)
# Requirement already satisfied: numpy in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torchvision) (2.4.2)
# Requirement already satisfied: importlib_metadata in /usr/lib/python3/dist-packages (from diffusers) (4.12.0)
# Requirement already satisfied: httpx<1.0.0 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from diffusers) (0.28.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from diffusers) (2026.2.19)
# Requirement already satisfied: requests in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from diffusers) (2.32.5)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from diffusers) (0.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from huggingface_hub) (1.3.2)
# Requirement already satisfied: packaging>=20.9 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from huggingface_hub) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typer in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from huggingface_hub) (0.24.1)
# Requirement already satisfied: scipy>=1.4.0 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from torchdiffeq) (1.17.0)
# Requirement already satisfied: psutil in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from accelerate) (7.2.2)
# Requirement already satisfied: lightning-utilities>=0.15.3 in /home/grwaqo/.local/lib/python3.12/site-packages (from torchmetrics) (0.15.3)
# Requirement already satisfied: anyio in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from httpx<1.0.0->diffusers) (4.12.1)
# Requirement already satisfied: certifi in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from httpx<1.0.0->diffusers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from httpx<1.0.0->diffusers) (1.0.9)
# Requirement already satisfied: idna in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from httpx<1.0.0->diffusers) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->diffusers) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib_metadata->diffusers) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from requests->diffusers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from requests->diffusers) (2.6.3)
# Requirement already satisfied: click>=8.2.1 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from typer->huggingface_hub) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from typer->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from typer->huggingface_hub) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from typer->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from rich>=12.3.0->typer->huggingface_hub) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from rich>=12.3.0->typer->huggingface_hub) (2.19.2)
# Requirement already satisfied: more-itertools in /usr/lib/python3/dist-packages (from zipp>=0.5->importlib_metadata->diffusers) (10.2.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !git clone https://github.com/arplaboratory/ThermalGen
# %cd ThermalGen
# Out:
# fatal: destination path 'ThermalGen' already exists and is not an empty directory.
# /home/grwaqo/Hackathon/new_ai_heat/AI_Heat_Resilience_Hackathon_Resources/Baseline_Model/ThermalGen

# %%
# FLIR dataset from https://github.com/arplaboratory/ThermalGen/tree/main/datasets_preprocess/FLIR
# %ls ..
# Out:
# 1.ThermalGenDemo_First.ipynb  demo_preds/
# 2.ThermalGen_MyDataset.ipynb  ThermalGen/

# %% [markdown]
# # Thermal Image Generation

# %%
# Load model
from thermalgen_demo import ThermalGenSIT
import torch
import torchvision.transforms.v2 as v2


device = "cuda" if torch.cuda.is_available() else "cpu"

eval_transform = v2.Compose([
    v2.ToImage(),
    v2.Resize((256, 256), interpolation=v2.InterpolationMode.BILINEAR, antialias=True),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
])

# You can switch to:
# "xjh19972/ThermalGen-L-2-concat"
# which the HF collection recommends
model_id = "xjh19972/ThermalGen-XL-2"

model = ThermalGenSIT.from_pretrained(model_id).to(device).eval()

# %%
import torch
from PIL import Image
from pathlib import Path
from torchvision.transforms.functional import to_pil_image
import torchvision.transforms.v2 as v2

# device
device = "cuda" if torch.cuda.is_available() else "cpu"

# transforms
eval_transform = v2.Compose([
    v2.ToImage(),
    v2.Resize((256, 256), interpolation=v2.InterpolationMode.BILINEAR, antialias=True),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
])

target_transform = v2.Compose([
    v2.ToImage(),
    v2.Resize((256, 256), interpolation=v2.InterpolationMode.BILINEAR, antialias=True),
    v2.ToDtype(torch.float32, scale=True),
])

# your folders
rgb_dir = Path("/home/grwaqo/Hackathon/new_ai_heat/AI_Heat_Resilience_Hackathon_Resources/Train/RGB")
thermal_dir = Path("/home/grwaqo/Hackathon/new_ai_heat/AI_Heat_Resilience_Hackathon_Resources/Train/Thermal")
#import os
#print(os.getcwd())
out_dir = Path("./demo_preds")
out_dir.mkdir(exist_ok=True)

comparison = Path("./demo_preds/comparison")
comparison.mkdir(exist_ok=True)

# select 10 demo samples
rgb_files = sorted(rgb_dir.glob("*.JPG"))[:10]
pairs = []
for rgb_path in rgb_files:
    thermal_path = thermal_dir / rgb_path.name
    if thermal_path.exists():
        print(thermal_path)
        pairs.append((rgb_path, thermal_path))

print("Demo pairs:", len(pairs))
# Out:
# /home/grwaqo/Hackathon/new_ai_heat/AI_Heat_Resilience_Hackathon_Resources/Train/Thermal/0.JPG
# /home/grwaqo/Hackathon/new_ai_heat/AI_Heat_Resilience_Hackathon_Resources/Train/Thermal/1.JPG
# /home/grwaqo/Hackathon/new_ai_heat/AI_Heat_Resilience_Hackathon_Resources/Train/Thermal/107.JPG
# /home/grwaqo/Hackathon/new_ai_heat/AI_Heat_Resilience_Hackathon_Resources/Train/Thermal/112.JPG
# /home/grwaqo/Hackathon/new_ai_heat/AI_Heat_Resilience_Hackathon_Resources/Train/Thermal/114.JPG
# /home/grwaqo/Hackathon/new_ai_heat/AI_Heat_Resilience_Hackathon_Resources/Train/Thermal/115.JPG
# /home/grwaqo/Hackathon/new_ai_heat/AI_Heat_Resilience_Hackathon_Resources/Train/Thermal/118.JPG
# /home/grwaqo/Hackathon/new_ai_heat/AI_Heat_Resilience_Hackathon_Resources/Train/Thermal/120.JPG
# Demo pairs: 8

# %%
from utils.metrics import calculate_psnr, calculate_ssim, calculate_lpips
import matplotlib.pyplot as plt
import numpy as np


all_psnr = []
all_ssim = []
all_lpips = []

for i, (rgb_path, thermal_path) in enumerate(pairs):
    rgb_image = Image.open(rgb_path).convert("RGB")
    target_image = Image.open(thermal_path)

    rgb = eval_transform(rgb_image).unsqueeze(0).to(device)
    target = target_transform(target_image).unsqueeze(0).to(device)

    with torch.no_grad():
        dataset_idx = torch.ones(1, dtype=torch.long, device=device) * 1000
        pred_thermal = model(rgb, dataset_idx)
        pred_thermal = pred_thermal * 0.5 + 0.5
        pred_thermal = torch.clamp(pred_thermal, 0, 1)

    # ensure GT is single-channel if needed
    if target.shape[1] > 1:
        target_gray = target[:, 0:1, :, :]
    else:
        target_gray = target

    psnr = calculate_psnr(pred_thermal, target_gray, None).compute().item()
    ssim = calculate_ssim(pred_thermal, target_gray, None).compute().item()
    lpips = calculate_lpips(pred_thermal, target_gray, None).compute().item()

    all_psnr.append(psnr)
    all_ssim.append(ssim)
    all_lpips.append(lpips)

    pred_img = to_pil_image(pred_thermal[0].cpu())
    pred_img.save(out_dir / f"{rgb_path.stem}_pred.png")

    print(f"[{i+1}/{len(pairs)}] {rgb_path.name} | PSNR={psnr:.4f} SSIM={ssim:.4f} LPIPS={lpips:.4f}")
    
    # Convert tensors to displayable images
    rgb_disp = rgb_image.resize((256, 256))
    pred_disp = to_pil_image(pred_thermal[0].cpu())
    gt_disp = target_image.resize((256, 256))
    
    # Create side-by-side plot
    fig, axes = plt.subplots(1, 3, figsize=(12, 4))
    
    axes[0].imshow(rgb_disp)
    axes[0].set_title("RGB")
    axes[0].axis("off")
    
    axes[1].imshow(pred_disp, cmap='inferno')
    axes[1].set_title("Prediction")
    axes[1].axis("off")
    
    axes[2].imshow(gt_disp, cmap='inferno')
    axes[2].set_title("Ground Truth")
    axes[2].axis("off")
    
    plt.tight_layout()
    
    # Save combined image
    save_path = out_dir / f"comparison/{rgb_path.stem}_comparison.png"
    plt.savefig(save_path)
    plt.close()
    
    # Optional: display inline in notebook
    plt.imshow(plt.imread(save_path))
    plt.axis("off")
    plt.show()
# Out:
# [1/8] 0.JPG | PSNR=6.9005 SSIM=0.1962 LPIPS=0.6668
# [2/8] 1.JPG | PSNR=7.6392 SSIM=0.1674 LPIPS=0.5689
# [3/8] 107.JPG | PSNR=8.7633 SSIM=0.2694 LPIPS=0.6066
# [4/8] 112.JPG | PSNR=6.9450 SSIM=0.2900 LPIPS=0.7145
# [5/8] 114.JPG | PSNR=6.1177 SSIM=0.2061 LPIPS=0.6262
# [6/8] 115.JPG | PSNR=4.7904 SSIM=0.2343 LPIPS=0.6830
# [7/8] 118.JPG | PSNR=8.3146 SSIM=0.2214 LPIPS=0.5827
# [8/8] 120.JPG | PSNR=5.1526 SSIM=0.2308 LPIPS=0.6524

# %%
print("Mean PSNR :", sum(all_psnr) / len(all_psnr))
print("Mean SSIM :", sum(all_ssim) / len(all_ssim))
print("Mean LPIPS:", sum(all_lpips) / len(all_lpips))
# Out:
# Mean PSNR : 6.827919125556946
# Mean SSIM : 0.22692595794796944
# Mean LPIPS: 0.6376383900642395

# %% [markdown]
# # Metrics
#
#
# *   Peak signal-to-noise ratio (PSNR)
# *   Structural similarity index measure (SSIM)
# *   Learned Perceptual Image Patch Similarity (LPIPS)
